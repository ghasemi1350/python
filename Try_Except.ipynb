# %% [markdown]
# #Exercises 11
#
# Exception Handling

# %% [markdown]
# Exercises1
# ![image.png](data:image/png;base64,...)

# %%
company='Filoger!'
print(car)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-29eca79d5b87> in <module>
#       1 company='Filoger!'
# ----> 2 print(car)
#
# NameError: name 'car' is not defined

# %%
try:
  company='Filoger!'
  print(car)
except Exception as error:
  print(error)
# Out:
# name 'car' is not defined

# %%
try:
  company='Filoger!'
  print(car)
except NameError as error:
  print(error)
# Out:
# name 'car' is not defined

# %% [markdown]
# Exercise 2
# ![image.png](data:image/png;base64,...)

# %%
company='Filgoer!
print(company)
# Out:
#   File "<ipython-input-80-286e1bc14b90>", line 1
#     company='Filgoer!
#                      ^
# SyntaxError: EOL while scanning string literal

# %%
try:
  company='Filoger!
  print(company)
except Exception as error:
  print(error)
# Out:
#   File "<ipython-input-81-7ff355b8f00b>", line 2
#     company='Filoger!
#                      ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# Exercise 3
#
# ![image.png](data:image/png;base64,...)

# %%
  company='Filoger!
  print(company+5)
# Out:
#   File "<ipython-input-82-05e5df541f21>", line 1
#     company='Filoger!
#                      ^
# SyntaxError: EOL while scanning string literal

# %%
try:
  company='Filoger!'
  print(company+5)
  
except Exception as error:
  print(error)
# Out:
# can only concatenate str (not "int") to str

# %%
try:
  company='Filoger!'
  print(company+5)
  
except:
  print(f' please concatenate str to str')
# Out:
#  please concatenate str to str

# %% [markdown]
# Exercies 4
#
# ![image.png](data:image/png;base64,...)

# %%
company='Filoger!'
print(company[25])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-85-e2981cbd09cf> in <module>
#       1 company='Filoger!'
# ----> 2 print(company[25])
#
# IndexError: string index out of range

# %%
try:
  company='Filoger!'
  print(company[25])

except:
  print("Exception:Index out of range")
# Out:
# Exception:Index out of range

# %%
try:
  company='Filoger!'
  print(company[25])

except Exception as error:
  print(error)
# Out:
# string index out of range

# %% [markdown]
# Exercises 5
#
# ![image.png](data:image/png;base64,...)

# %%
dict={'python':2, 'DIP':7 , 'DL': 8}
print(dict['CV'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-1737cfa2add0> in <module>
#       1 dict={'python':2, 'DIP':7 , 'DL': 8}
# ----> 2 print(dict['CV'])
#
# KeyError: 'CV'

# %%
try:
    dict={'python':2, 'DIP':7 , 'DL': 8}
    print(dict['CV'])
except KeyError:
    print('Can not find "something')
# Out:
# Can not find "something

# %%
try:
    dict={'python':2, 'DIP':7 , 'DL': 8}
    print(dict['CV'])
except Exception as error:
    print(f'can not find key dictionary {error}')
# Out:
# can not find key dictionary 'CV'

# %% [markdown]
# Exercise 6
#
# ![image.png](data:image/png;base64,...)

# %%
code='45145GT'
int(code)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-d53eed92235b> in <module>
#       1 code='45145GT'
# ----> 2 int(code)
#
# ValueError: invalid literal for int() with base 10: '45145GT'

# %%
try:
  code='45145GT'
  int(code)
except ValueError as error:
  print(error)
# Out:
# invalid literal for int() with base 10: '45145GT'

# %%
try:
  code='45145GT'
  int(code)
except:
  print('Can not convert', code ,"to int")
# Out:
# Can not convert 45145GT to int
